# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Temp/DentalClinic/cleaned.csv")
df.head(5)
# Out:
#    patient_id     patient_name  gender  age  visit_date consulted_by  \
# 0   MLPT00001      Ngozi Okoro  Female   54  2023-01-02    Dr. Kajal
# 1   MLPT00002      Chinedu Eze    Male   73  2023-01-02    Dr. Karan
# 2   MLPT00003     Fatima Bello  Female   57  2023-01-03    Dr. Karan
# 3   MLPT00004     Emeka Nwafor    Male   73  2023-01-03    Dr. Karan
# 4   MLPT00005  Adewale Adeyemi    Male   16  2023-01-03    Dr. Karan
# 5   MLPT00006   Jagdish Prasad    Male   57  2023-01-04    Dr. Kajal
# 6   MLPT00007       Aisha Khan  Female   67  2023-01-04    Dr. Kajal
# 7   MLPT00008     Raghav Singh    Male   67  2023-01-05    Dr. Karan
# 8   MLPT00009      Naina Gupta  Female   13  2023-01-05    Dr. Kajal
# 9   MLPT00010      Poonam Devi  Female   30  2023-01-06    Dr. Kajal
# 10  MLPT00011      Kajal Singh  Female   80  2023-01-06    Dr. Karan
# 11  MLPT00012        Gia Patel  Female   73  2023-01-07    Dr. Kajal
# 12  MLPT00013      Kajal Singh  Female   53  2023-01-07    Dr. Kajal
# ...

# %% [markdown]
# Cleaning Check-up

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 897 entries, 0 to 896
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patient_id      897 non-null    object
#  1   patient_name    897 non-null    object
#  2   gender          897 non-null    object
#  3   age             897 non-null    int64
#  4   visit_date      897 non-null    object
#  5   consulted_by    897 non-null    object
#  6   dental_camp     897 non-null    object
#  7   xray_done       897 non-null    object
#  8   patient_type    897 non-null    object
#  9   treatment_type  897 non-null    object
#  10  treatment_cost  897 non-null    float64
#  11  xray_cost       897 non-null    float64
#  12  opd_cost        897 non-null    float64
#  13  lab_charges     897 non-null    float64
#  14  discount        897 non-null    float64
#  15  total_paid      897 non-null    float64
#  16  due             897 non-null    float64
# ...

# %%
df.describe().T
# Out:
#                 count         mean          std  min    25%    50%    75%  \
# age             897.0    42.100334    22.005401  5.0   22.0   43.0   60.0
# treatment_cost  897.0  2064.214047  5706.665793  0.0    0.0    0.0  656.0
# xray_cost       897.0    51.505017    71.264631  0.0    0.0    0.0  150.0
# opd_cost        897.0   121.293200    97.761211  0.0    0.0  200.0  200.0
# lab_charges     897.0   468.171683  1505.311653  0.0    0.0    0.0    0.0
# discount        897.0    53.778372   160.191473  0.0    0.0    0.0   50.0
# total_paid      897.0  2113.243924  5426.072148  0.0  200.0  350.0  621.0
# due             897.0    69.989967   615.469120  0.0    0.0    0.0    0.0
# profit          897.0  1645.072241  3966.398307  0.0  200.0  350.0  621.0
#
#                     max
# age                80.0
# treatment_cost  29029.0
# xray_cost         150.0
# opd_cost          200.0
# lab_charges      9160.0
# discount         1500.0
# total_paid      29029.0
# due              9201.0
# ...

# %%
df.isnull().sum()
# Out:
# patient_id        0
# patient_name      0
# gender            0
# age               0
# visit_date        0
# consulted_by      0
# dental_camp       0
# xray_done         0
# patient_type      0
# treatment_type    0
# treatment_cost    0
# xray_cost         0
# opd_cost          0
# lab_charges       0
# discount          0
# total_paid        0
# due               0
# profit            0
# payment_method    0
# dtype: int64

# %%
df.isnull().mean().sort_values(ascending=False)
# Out:
# patient_id        0.0
# treatment_cost    0.0
# profit            0.0
# due               0.0
# total_paid        0.0
# discount          0.0
# lab_charges       0.0
# opd_cost          0.0
# xray_cost         0.0
# treatment_type    0.0
# patient_name      0.0
# patient_type      0.0
# xray_done         0.0
# dental_camp       0.0
# consulted_by      0.0
# visit_date        0.0
# age               0.0
# gender            0.0
# payment_method    0.0
# dtype: float64

# %% [markdown]
# Outliers

# %%
df.columns
# Out:
# Index(['patient_id', 'patient_name', 'gender', 'age', 'visit_date',
#        'consulted_by', 'dental_camp', 'xray_done', 'patient_type',
#        'treatment_type', 'treatment_cost', 'xray_cost', 'opd_cost',
#        'lab_charges', 'discount', 'total_paid', 'due', 'profit',
#        'payment_method'],
#       dtype='object')

# %%
df[['treatment_cost','xray_cost','opd_cost','lab_charges','discount','total_paid','due','profit']].describe()
# Out:
#        treatment_cost   xray_cost    opd_cost  lab_charges     discount  \
# count      897.000000  897.000000  897.000000   897.000000   897.000000
# mean      2064.214047   51.505017  121.293200   468.171683    53.778372
# std       5706.665793   71.264631   97.761211  1505.311653   160.191473
# min          0.000000    0.000000    0.000000     0.000000     0.000000
# 25%          0.000000    0.000000    0.000000     0.000000     0.000000
# 50%          0.000000    0.000000  200.000000     0.000000     0.000000
# 75%        656.000000  150.000000  200.000000     0.000000    50.000000
# max      29029.000000  150.000000  200.000000  9160.000000  1500.000000
#
#          total_paid          due        profit
# count    897.000000   897.000000    897.000000
# mean    2113.243924    69.989967   1645.072241
# std     5426.072148   615.469120   3966.398307
# min        0.000000     0.000000      0.000000
# 25%      200.000000     0.000000    200.000000
# ...

# %%
Q1 = df['treatment_cost'].quantile(0.25)
Q3 = df['treatment_cost'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['treatment_cost'] < lower_bound) | (df['treatment_cost'] > upper_bound)]

# %%
outliers
# Out:
#     patient_id    patient_name  gender  age  visit_date consulted_by  \
# 6    MLPT00007      Aisha Khan  Female   67  2023-01-04    Dr. Kajal
# 15   MLPT00016  Ishaan Chauhan    Male   43  2023-01-11    Dr. Kajal
# 19   MLPT00020      Uday Singh    Male   73  2023-01-13    Dr. Kajal
# 27   MLPT00028    Pranav Kumar    Male   47  2023-01-17    Dr. Kajal
# 34   MLPT00035       Jia Verma  Female   72  2023-01-23    Dr. Kajal
# ..         ...             ...     ...  ...         ...          ...
# 857  MLPT00858    Advait Singh    Male   22  2024-12-02    Dr. Kajal
# 858  MLPT00859     Vanya Gupta  Female   59  2024-12-03    Dr. Kajal
# 865  MLPT00866     Kaira Yadav  Female   54  2024-12-03    Dr. Karan
# 868  MLPT00869    Ishita Singh  Female   68  2024-12-03    Dr. Kajal
# 879  MLPT00880     Arnav Gupta    Male   19  2024-12-05    Dr. Kajal
#
#     dental_camp xray_done patient_type treatment_type  treatment_cost  \
# ...

# %%
Q1 = df['xray_cost'].quantile(0.25)
Q3 = df['xray_cost'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['xray_cost'] < lower_bound) | (df['xray_cost'] > upper_bound)]

# %%
outliers
# Out:
# Empty DataFrame
# Columns: [patient_id, patient_name, gender, age, visit_date, consulted_by, dental_camp, xray_done, patient_type, treatment_type, treatment_cost, xray_cost, opd_cost, lab_charges, discount, total_paid, due, profit, payment_method]
# Index: []

# %%
Q1 = df['opd_cost'].quantile(0.25)
Q3 = df['opd_cost'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['opd_cost'] < lower_bound) | (df['opd_cost'] > upper_bound)]

# %%
outliers
# Out:
# Empty DataFrame
# Columns: [patient_id, patient_name, gender, age, visit_date, consulted_by, dental_camp, xray_done, patient_type, treatment_type, treatment_cost, xray_cost, opd_cost, lab_charges, discount, total_paid, due, profit, payment_method]
# Index: []

# %%
Q1 = df['lab_charges'].quantile(0.25)
Q3 = df['lab_charges'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['lab_charges'] < lower_bound) | (df['lab_charges'] > upper_bound)]

# %%
outliers
# Out:
#     patient_id    patient_name  gender  age  visit_date consulted_by  \
# 15   MLPT00016  Ishaan Chauhan    Male   43  2023-01-11    Dr. Kajal
# 19   MLPT00020      Uday Singh    Male   73  2023-01-13    Dr. Kajal
# 34   MLPT00035       Jia Verma  Female   72  2023-01-23    Dr. Kajal
# 40   MLPT00041    Zeeshan Khan    Male   54  2023-01-27    Dr. Kajal
# 41   MLPT00042   Vandana Gupta  Female   46  2023-01-27    Dr. Karan
# ..         ...             ...     ...  ...         ...          ...
# 857  MLPT00858    Advait Singh    Male   22  2024-12-02    Dr. Kajal
# 858  MLPT00859     Vanya Gupta  Female   59  2024-12-03    Dr. Kajal
# 865  MLPT00866     Kaira Yadav  Female   54  2024-12-03    Dr. Karan
# 868  MLPT00869    Ishita Singh  Female   68  2024-12-03    Dr. Kajal
# 879  MLPT00880     Arnav Gupta    Male   19  2024-12-05    Dr. Kajal
#
#     dental_camp xray_done patient_type treatment_type  treatment_cost  \
# ...

# %%
Q1 = df['discount'].quantile(0.25)
Q3 = df['discount'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['discount'] < lower_bound) | (df['discount'] > upper_bound)]

# %%
outliers
# Out:
#     patient_id  patient_name  gender  age  visit_date consulted_by  \
# 9    MLPT00010   Poonam Devi  Female   30  2023-01-06    Dr. Kajal
# 10   MLPT00011   Kajal Singh  Female   80  2023-01-06    Dr. Karan
# 13   MLPT00014   Manoj Kumar    Male   65  2023-01-09    Dr. Kajal
# 18   MLPT00019   Rishi Yadav    Male   62  2023-01-12    Dr. Kajal
# 19   MLPT00020    Uday Singh    Male   73  2023-01-13    Dr. Kajal
# ..         ...           ...     ...  ...         ...          ...
# 862  MLPT00863    Dhruv Jain    Male   69  2024-12-03    Dr. Kajal
# 863  MLPT00864  Saisha Singh  Female   56  2024-12-03    Dr. Karan
# 869  MLPT00870  Deepa Sharma  Female   80  2024-12-03    Dr. Kajal
# 872  MLPT00873   Anika Patel  Female   59  2024-12-04    Dr. Kajal
# 876  MLPT00877    Om Prakash    Male   79  2024-12-04    Dr. Karan
#
#     dental_camp xray_done patient_type treatment_type  treatment_cost  \
# 9            No       Yes  First Visit    OPD + X-Ray             0.0
# ...

# %%
Q1 = df['total_paid'].quantile(0.25)
Q3 = df['total_paid'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['total_paid'] < lower_bound) | (df['total_paid'] > upper_bound)]

# %%
outliers
# Out:
#     patient_id    patient_name  gender  age  visit_date consulted_by  \
# 5    MLPT00006  Jagdish Prasad    Male   57  2023-01-04    Dr. Kajal
# 6    MLPT00007      Aisha Khan  Female   67  2023-01-04    Dr. Kajal
# 15   MLPT00016  Ishaan Chauhan    Male   43  2023-01-11    Dr. Kajal
# 19   MLPT00020      Uday Singh    Male   73  2023-01-13    Dr. Kajal
# 27   MLPT00028    Pranav Kumar    Male   47  2023-01-17    Dr. Kajal
# ..         ...             ...     ...  ...         ...          ...
# 857  MLPT00858    Advait Singh    Male   22  2024-12-02    Dr. Kajal
# 858  MLPT00859     Vanya Gupta  Female   59  2024-12-03    Dr. Kajal
# 865  MLPT00866     Kaira Yadav  Female   54  2024-12-03    Dr. Karan
# 868  MLPT00869    Ishita Singh  Female   68  2024-12-03    Dr. Kajal
# 879  MLPT00880     Arnav Gupta    Male   19  2024-12-05    Dr. Kajal
#
#     dental_camp xray_done patient_type treatment_type  treatment_cost  \
# ...

# %%
Q1 = df['due'].quantile(0.25)
Q3 = df['due'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['due'] < lower_bound) | (df['due'] > upper_bound)]

# %%
outliers
# Out:
#     patient_id   patient_name  gender  age  visit_date consulted_by  \
# 70   MLPT00071     Manav Jain    Male   52  2023-02-17    Dr. Kajal
# 100  MLPT00101  Vivaan Sharma    Male   50  2023-03-14    Dr. Kajal
# 102  MLPT00103    Arnav Gupta    Male   66  2023-03-15    Dr. Kajal
# 111  MLPT00112     Uday Singh    Male   10  2023-03-25    Dr. Kajal
# 213  MLPT00214    Aryan Patel    Male   26  2023-06-08    Dr. Kajal
# 226  MLPT00227   Tanisha Jain  Female   33  2023-06-20    Dr. Kajal
# 296  MLPT00297    Avani Yadav  Female    6  2023-08-23    Dr. Kajal
# 329  MLPT00330  Sandeep Gupta    Male   38  2023-09-20    Dr. Kajal
# 383  MLPT00384    Bhavya Jain  Female   47  2023-11-05    Dr. Karan
# 396  MLPT00397   Akshat Kumar    Male   48  2023-11-10    Dr. Kajal
# 412  MLPT00413   Aarav Sharma    Male   41  2023-11-29    Dr. Kajal
# 493  MLPT00494   Bharat Singh    Male   41  2024-01-19    Dr. Kajal
# 560  MLPT00561     Om Prakash    Male   16  2024-03-04    Dr. Kajal
# ...

# %%
Q1 = df['profit'].quantile(0.25)
Q3 = df['profit'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['profit'] < lower_bound) | (df['profit'] > upper_bound)]

# %%
outliers
# Out:
#     patient_id    patient_name  gender  age  visit_date consulted_by  \
# 5    MLPT00006  Jagdish Prasad    Male   57  2023-01-04    Dr. Kajal
# 6    MLPT00007      Aisha Khan  Female   67  2023-01-04    Dr. Kajal
# 15   MLPT00016  Ishaan Chauhan    Male   43  2023-01-11    Dr. Kajal
# 19   MLPT00020      Uday Singh    Male   73  2023-01-13    Dr. Kajal
# 27   MLPT00028    Pranav Kumar    Male   47  2023-01-17    Dr. Kajal
# ..         ...             ...     ...  ...         ...          ...
# 857  MLPT00858    Advait Singh    Male   22  2024-12-02    Dr. Kajal
# 858  MLPT00859     Vanya Gupta  Female   59  2024-12-03    Dr. Kajal
# 865  MLPT00866     Kaira Yadav  Female   54  2024-12-03    Dr. Karan
# 868  MLPT00869    Ishita Singh  Female   68  2024-12-03    Dr. Kajal
# 879  MLPT00880     Arnav Gupta    Male   19  2024-12-05    Dr. Kajal
#
#     dental_camp xray_done patient_type treatment_type  treatment_cost  \
# ...
